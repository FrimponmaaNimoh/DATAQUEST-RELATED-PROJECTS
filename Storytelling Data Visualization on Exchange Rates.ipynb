# %% [markdown]
# ### Introducing the Dataset

# %%
import pandas as pd

# %%
exchange_rates=pd.read_csv('euro-daily-hist_1999_2020.csv')

# %%
exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2021-01-08               1.5758           1.9558            6.5748
# 1   2021-01-07               1.5836           1.9558            6.5172
# 2   2021-01-06               1.5824           1.9558            6.5119
# 3   2021-01-05               1.5927           1.9558            6.5517
# 4   2021-01-04               1.5928           1.9558            6.3241
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.5543         1.0827                   7.9184              NaN
# 1             1.5601         1.0833                   7.9392              NaN
# 2             1.5640         1.0821                   7.9653              NaN
# 3             1.5651         1.0803                   7.9315              NaN
# 4             1.5621         1.0811                   7.9484              NaN
#
# ...

# %%
exchange_rates.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 5694   1999-01-08               1.8406              NaN               NaN
# 5695   1999-01-07               1.8474              NaN               NaN
# 5696   1999-01-06               1.8820              NaN               NaN
# 5697   1999-01-05               1.8944              NaN               NaN
# 5698   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 5694             1.7643         1.6138                      NaN
# 5695             1.7602         1.6165                      NaN
# 5696             1.7711         1.6116                      NaN
# 5697             1.7965         1.6123                      NaN
# 5698             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# ...

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              5699 non-null   object
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %% [markdown]
# #### Deduction from dataset
#
# 1) There are 5699 rows and 41 columns.
#
# 2) There a null values in some columns.eg Slovenian tolar, Slovak koruna,Latvian lats, Maltese lira
#
# 3) There are 3 float type columns and 38 object type columns which must be converted to float types because they all numbers. Period/unit column must also be made a datetime object type

# %% [markdown]
# ### DATA CLEANING

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time'},
                      inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)

# %%
exchange_rates.columns
# Out:
# Index(['Time', '[Australian dollar ]', '[Bulgarian lev ]', '[Brazilian real ]',
#        '[Canadian dollar ]', '[Swiss franc ]', '[Chinese yuan renminbi ]',
#        '[Cypriot pound ]', '[Czech koruna ]', '[Danish krone ]',
#        '[Estonian kroon ]', '[UK pound sterling ]', '[Greek drachma ]',
#        '[Hong Kong dollar ]', '[Croatian kuna ]', '[Hungarian forint ]',
#        '[Indonesian rupiah ]', '[Israeli shekel ]', '[Indian rupee ]',
#        '[Iceland krona ]', '[Japanese yen ]', '[Korean won ]',
#        '[Lithuanian litas ]', '[Latvian lats ]', '[Maltese lira ]',
#        '[Mexican peso ]', '[Malaysian ringgit ]', '[Norwegian krone ]',
#        '[New Zealand dollar ]', '[Philippine peso ]', '[Polish zloty ]',
#        '[Romanian leu ]', '[Russian rouble ]', '[Swedish krona ]',
#        '[Singapore dollar ]', '[Slovenian tolar ]', '[Slovak koruna ]',
#        '[Thai baht ]', '[Turkish lira ]', 'US_dollar',
#        '[South African rand ]'],
#       dtype='object')

# %%
euro_to_dollar=exchange_rates[['Time','US_dollar']]

# %%
euro_to_dollar.head()
# Out:
#         Time US_dollar
# 0 1999-01-04    1.1789
# 1 1999-01-05    1.1790
# 2 1999-01-06    1.1743
# 3 1999-01-07    1.1632
# 4 1999-01-08    1.1659

# %%
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.0888     6
#           ..
# 0.8644     1
# 1.4723     1
# 0.9149     1
# 1.2068     1
# 1.0487     1
# Name: US_dollar, Length: 3528, dtype: int64

# %%
euro_to_dollar=euro_to_dollar[euro_to_dollar['US_dollar'] != '-']

# %%
euro_to_dollar['US_dollar']=euro_to_dollar['US_dollar'].astype(float)

# %%
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5637 entries, 0 to 5698
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       5637 non-null   datetime64[ns]
#  1   US_dollar  5637 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 132.1 KB

# %% [markdown]
# ### GENERATING LINE PLOT

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.plot(euro_to_dollar['Time'],
         euro_to_dollar['US_dollar'])
plt.show()

# %% [markdown]
# ### ROLLING_MEAN

# %%
euro_to_dollar['rolling_mean']=euro_to_dollar['US_dollar'].rolling(30).mean()

# %%
euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean
# 0    1999-01-04     1.1789           NaN
# 1    1999-01-05     1.1790           NaN
# 2    1999-01-06     1.1743           NaN
# 3    1999-01-07     1.1632           NaN
# 4    1999-01-08     1.1659           NaN
# ...         ...        ...           ...
# 5694 2021-01-04     1.2296      1.211170
# 5695 2021-01-05     1.2271      1.212530
# 5696 2021-01-06     1.2338      1.213987
# 5697 2021-01-07     1.2276      1.215357
# 5698 2021-01-08     1.2250      1.216557
#
# [5637 rows x 3 columns]

# %% [markdown]
# ### STORY TELLING DATA VISUALIZATION

# %% [markdown]
# We show comparatively how the euro-dollar rate changed under the last three US presidents (George W. Bush (2001-2008), Barack Obama (2009-2016), and Donald Trump (2017-2020)). We can use a line plot.

# %%
euro_to_dollar['Year']=euro_to_dollar['Time'].dt.year

# %%
euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean  Year
# 0    1999-01-04     1.1789           NaN  1999
# 1    1999-01-05     1.1790           NaN  1999
# 2    1999-01-06     1.1743           NaN  1999
# 3    1999-01-07     1.1632           NaN  1999
# 4    1999-01-08     1.1659           NaN  1999
# ...         ...        ...           ...   ...
# 5694 2021-01-04     1.2296      1.211170  2021
# 5695 2021-01-05     1.2271      1.212530  2021
# 5696 2021-01-06     1.2338      1.213987  2021
# 5697 2021-01-07     1.2276      1.215357  2021
# 5698 2021-01-08     1.2250      1.216557  2021
#
# [5637 rows x 4 columns]

# %%
print(euro_to_dollar[euro_to_dollar['Year']==2001])
# Out:
#           Time  US_dollar  rolling_mean  Year
# 521 2001-01-02     0.9423      0.883343  2001
# 522 2001-01-03     0.9530      0.886660  2001
# 523 2001-01-04     0.9458      0.889893  2001
# 524 2001-01-05     0.9545      0.893463  2001
# 525 2001-01-08     0.9497      0.897023  2001
# ..         ...        ...           ...   ...
# 773 2001-12-20     0.8973      0.888723  2001
# 774 2001-12-21     0.8943      0.888767  2001
# 775 2001-12-24     0.8798      0.888363  2001
# 778 2001-12-27     0.8823      0.888300  2001
# 779 2001-12-28     0.8813      0.888333  2001
#
# [254 rows x 4 columns]

# %%
bool_bush=(euro_to_dollar['Year']>=2001) & (euro_to_dollar['Year']<2009)

# %%
bush=euro_to_dollar[bool_bush]

# %%
bush
# Out:
#            Time  US_dollar  rolling_mean  Year
# 521  2001-01-02     0.9423      0.883343  2001
# 522  2001-01-03     0.9530      0.886660  2001
# 523  2001-01-04     0.9458      0.889893  2001
# 524  2001-01-05     0.9545      0.893463  2001
# 525  2001-01-08     0.9497      0.897023  2001
# ...         ...        ...           ...   ...
# 2601 2008-12-23     1.3978      1.303717  2008
# 2602 2008-12-24     1.4005      1.308633  2008
# 2605 2008-12-29     1.4270      1.314450  2008
# 2606 2008-12-30     1.4098      1.319193  2008
# 2607 2008-12-31     1.3917      1.323383  2008
#
# [2046 rows x 4 columns]

# %%
bool_obama=(euro_to_dollar['Year']>=2009) & (euro_to_dollar['Year']<2017)

# %%
obama=euro_to_dollar[bool_obama]
obama
# Out:
#            Time  US_dollar  rolling_mean  Year
# 2609 2009-01-02     1.3866      1.327427  2009
# 2610 2009-01-05     1.3582      1.330587  2009
# 2611 2009-01-06     1.3332      1.333220  2009
# 2612 2009-01-07     1.3595      1.336530  2009
# 2613 2009-01-08     1.3617      1.339343  2009
# ...         ...        ...           ...   ...
# 4667 2016-12-23     1.0446      1.059800  2016
# 4668 2016-12-27     1.0445      1.058693  2016
# 4669 2016-12-28     1.0401      1.057480  2016
# 4670 2016-12-29     1.0453      1.056650  2016
# 4671 2016-12-30     1.0541      1.056063  2016
#
# [2050 rows x 4 columns]

# %%
bool_trump=(euro_to_dollar['Year']>=2017) & (euro_to_dollar['Year']<2021)

# %%
trump=euro_to_dollar[bool_trump]
trump
# Out:
#            Time  US_dollar  rolling_mean  Year
# 4672 2017-01-02     1.0465      1.055517  2017
# 4673 2017-01-03     1.0385      1.054697  2017
# 4674 2017-01-04     1.0437      1.054097  2017
# 4675 2017-01-05     1.0501      1.053760  2017
# 4676 2017-01-06     1.0589      1.053897  2017
# ...         ...        ...           ...   ...
# 5689 2020-12-24     1.2193      1.204173  2020
# 5690 2020-12-28     1.2219      1.205520  2020
# 5691 2020-12-29     1.2259      1.206950  2020
# 5692 2020-12-30     1.2281      1.208280  2020
# 5693 2020-12-31     1.2271      1.209623  2020
#
# [1022 rows x 4 columns]

# %%
bush_obama_trump=euro_to_dollar[(euro_to_dollar['Year']>=2001) & (euro_to_dollar['Year']<2021)]
bush_obama_trump
# Out:
#            Time  US_dollar  rolling_mean  Year
# 521  2001-01-02     0.9423      0.883343  2001
# 522  2001-01-03     0.9530      0.886660  2001
# 523  2001-01-04     0.9458      0.889893  2001
# 524  2001-01-05     0.9545      0.893463  2001
# 525  2001-01-08     0.9497      0.897023  2001
# ...         ...        ...           ...   ...
# 5689 2020-12-24     1.2193      1.204173  2020
# 5690 2020-12-28     1.2219      1.205520  2020
# 5691 2020-12-29     1.2259      1.206950  2020
# 5692 2020-12-30     1.2281      1.208280  2020
# 5693 2020-12-31     1.2271      1.209623  2020
#
# [5118 rows x 4 columns]

# %% [markdown]
# Below, you'll notice we used matplotlib's functional approach to build the graphs. We use this approach because it offers more flexibility in arranging the subplots:
#
# We first build three of the graphs on a 2-by-3 grid (this grid should have six subplots, but we only build three; the bottom row remains empty).
#
# We then build only the bottom graph of a 2-by-1 grid (this grid should have two subplots; the top row remains empty).
#
# The two grids are merged, and we end up with three graphs on the top row and one graph on the bottom row.

# %%
import matplotlib.style as style

# %% [markdown]
# #Unfortunately, the x-coordinates (behind the datetime units) are not fixed in matplotlib (to fix them, you’d need a slightly more complicated coding approach), so the solution here is to use ax.get_xticks() and ax.get_yticks() to see what are the coordinates and then adjust your input coordinates accordingly.

# %%
### Adding the FiveThirtyEight style
style.use('fivethirtyeight')

### Adding the subplots
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)
ax4 = plt.subplot(2,1,2)
axes = [ax1, ax2, ax3, ax4]

### Changes to all the subplots
for ax in axes:
    ax.set_ylim(0.8, 1.7)
    ax.set_yticks([1.0, 1.2, 1.4, 1.6])
    ax.set_yticklabels(['1.0', '1.2','1.4', '1.6'],
                   alpha=0.3)
    ax.grid(alpha=0.5)    
    
### Ax1: Bush
ax1.plot(bush['Time'], bush['rolling_mean'],
        color='#BF5FFF')
ax1.set_xticklabels(['', '2001', '', '2003', '', '2005', '',
                     '2007', '', '2009'],
                   alpha=0.3)
print(ax1.get_xticks())
print(ax1.get_yticks())
ax1.text(731581, 1.92, 'BUSH', fontsize=18, weight='bold',
        color='#BF5FFF')
ax1.text(731216, 1.8, '(2001-2009)', weight='bold',
        alpha=0.3)

### Ax2: Obama
ax2.plot(obama['Time'], obama['rolling_mean'],
        color='#ffa500')
ax2.set_xticklabels(['', '2009', '', '2011', '', '2013', '',
                     '2015', '', '2017'],
                   alpha=0.3)
print(ax2.get_xticks())
print(ax2.get_yticks())
ax2.text(734503, 1.92, 'OBAMA', fontsize=18, weight='bold',
        color='#ffa500')
ax2.text(734138, 1.8, '(2009-2017)', weight='bold',
         alpha=0.3)


### Ax3: Trump
ax3.plot(trump['Time'], trump['rolling_mean'],
        color='#00B2EE')
ax3.set_xticklabels(['2017', '', '2018', '', '2019', '',
                     '2020', '', '2021'],
                   alpha=0.3)
print(ax3.get_xticks())
print(ax3.get_yticks())
ax3.text(736876, 1.92, 'TRUMP', fontsize=18, weight='bold',
        color='#00B2EE')
ax3.text(736695, 1.8, '(2017-2021)', weight='bold',
         alpha=0.3)

### Ax4: Bush-Obama-Trump
ax4.plot(bush['Time'], bush['rolling_mean'],
        color='#BF5FFF')
ax4.plot(obama['Time'], obama['rolling_mean'],
        color='#ffa500')
ax4.plot(trump['Time'], trump['rolling_mean'],
        color='#00B2EE')
ax4.grid(alpha=0.5)

print(ax4.get_xticks())
print(ax4.get_yticks())

ax4.set_xticks([])

### Adding a title and a subtitle
ax1.text(730120, 2.35, 'EURO-USD rate averaged 1.22 under the last three US presidents',
         fontsize=20, weight='bold')
ax1.text(730120, 2.14, '''EURO-USD exchange rates under George W. Bush (2001 - 2009), Barack Obama (2009-2017),
and Donald Trump (2017-2021)''',
        fontsize=16)

### Adding a signature
ax4.text(730110, 0.65, '©DATAQUEST' + ' '*103 + 'Source: European Central Bank',
        color = '#f0f0f0', backgroundcolor = '#4d4d4d',
        size=14)
# Out:
# [730120. 730486. 730851. 731216. 731581. 731947. 732312. 732677. 733042.
#  733408.]
# [1.  1.2 1.4 1.6]
# [733042. 733408. 733773. 734138. 734503. 734869. 735234. 735599. 735964.
#  736330.]
# [1.  1.2 1.4 1.6]
# [736330. 736511. 736695. 736876. 737060. 737241. 737425. 737607. 737791.]
# [1.  1.2 1.4 1.6]
# [730120. 731581. 733042. 734503. 735964. 737425. 738886.]
# [1.  1.2 1.4 1.6]
# Text(730110, 0.65, '©DATAQUEST                                                                                                       Source: European Central Bank')

# %% [markdown]
# ### Financial Crisis Example

# %%
financial_crisis = euro_to_dollar.copy(
                   )[(euro_to_dollar['Time'].dt.year >= 2006
                   ) & (euro_to_dollar['Time'].dt.year <= 2009)]
financial_crisis_7_8 = euro_to_dollar.copy(
                   )[(euro_to_dollar.Time.dt.year >= 2007
                   ) & (euro_to_dollar.Time.dt.year <= 2008)]

# %%
### using the FiveThirtyEight style


### Adding the plot
fig,ax = plt.subplots(figsize=(8,3))
ax.plot(financial_crisis['Time'],
        financial_crisis['rolling_mean'],
        linewidth=1, color='#A6D785')

### Highlighting the 2007-2008 period
ax.plot(financial_crisis_7_8['Time'],
        financial_crisis_7_8['rolling_mean'],
        linewidth=3, color='#e23d28')


print(ax.get_xticks())
print(ax.get_yticks())


### Highlihting the peak of the crisis
ax.axvspan(xmin=733130, xmax=733274, ymin=0.09,
           alpha=0.3, color='grey')


### Adding separate tick labels
ax.set_xticklabels([])
ax.set_yticklabels([])

x = 732275
for year in ['2006', '2007', '2008', '2009', '2010']:
    ax.text(x, 1.13, year, alpha=0.5, fontsize=11)
    x += 365

y = 1.193 
for rate in ['1.2', '1.3', '1.4', '1.5']:
    ax.text(732250, y, rate, alpha=0.5, fontsize=11)
    y += 0.1

### Adding a title and a subtitle    
ax.text(732312, 1.67, "Euro-USD rate peaked at 1.59 during 2007-2008's financial crisis",
        weight='bold')
ax.text(732312, 1.63, 'Euro-USD exchange rates between 2006 and 2010',
        size=12)

### Adding a signature
ax.text(732312, 1.07, '©DATAQUEST' + ' '*94 + 'Source: European Central Bank',
        color = '#f0f0f0', backgroundcolor = '#4d4d4d',
        size=10)

### Add some transparency to the grid
ax.grid(alpha=0.5)

plt.show()
# Out:
# [732312. 732493. 732677. 732858. 733042. 733224. 733408. 733589. 733773.]
# [1.1 1.2 1.3 1.4 1.5 1.6]
